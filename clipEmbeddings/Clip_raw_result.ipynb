# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import json
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import csv
# THIS IS FOR TRAIN IDIOM DATASET
# 加载模型和处理器
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# 指定主文件夹路径和 JSON 文件路径
main_folder_path = "/content/drive/MyDrive/train"  # 替换为你的实际路径
json_file_path = "/content/drive/MyDrive/train_idiom_mean.json"   # 替换为你的 JSON 文件路径


# 加载 JSON 文件
with open(json_file_path, "r", encoding="utf-8") as json_file:
    compound_definitions = json.load(json_file)

# 初始化结果存储
results = []

# 遍历 JSON 中的 compound 定义
for compound_name, compound_text in compound_definitions.items():
    compound_path = os.path.join(main_folder_path, compound_name)

    # 检查文件夹是否存在
    if not os.path.isdir(compound_path):
        print(f"Skipping compound: {compound_name} (folder does not exist)")
        continue

    print(f"Processing compound: {compound_name}")

    # 将 compound 和解释拼接为一个完整文本
    combined_text = f"Compound: {compound_name}. Explanation: {compound_text}"

    # 用于存储当前 compound 的图片及其 logits
    image_logits = []

    # 遍历子文件夹中的图片
    for filename in os.listdir(compound_path):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):  # 仅处理图片文件
            image_path = os.path.join(compound_path, filename)

            # 打开图片
            try:
                image = Image.open(image_path)
            except Exception as e:
                print(f"Error opening image {filename}: {e}")
                continue

            # 使用 compound 和解释拼接后的文本作为输入
            inputs = processor(
                text=[combined_text],  # 拼接后的文本输入
                images=image,
                return_tensors="pt",
                padding=True
            )

            # 获取模型输出
            outputs = model(**inputs)
            logits_per_image = outputs.logits_per_image  # 获取 logits 值

            # 打印日志信息
            print(f"Compound: {compound_name}")
            print(f"Image ID: {filename}")  # 保留文件名及后缀
            print(f"Input Text: {combined_text}")
            print(f"Logits: {logits_per_image}")
            print("-" * 50)

            # 保存图片文件名（包含后缀）和 logits
            image_logits.append((filename, logits_per_image.item()))

    # 按 logits 从大到小排序
    sorted_images = sorted(image_logits, key=lambda x: x[1], reverse=True)

    # 提取排序后的图片文件名列表
    expected_order = [img[0] for img in sorted_images]

    # 保存 compound 和排序列表
    results.append([compound_name, expected_order])

# 将结果保存为 TSV 文件
output_file = "train_idiom.tsv"
with open(output_file, "w", newline="", encoding="utf-8") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    writer.writerow(["compound", "expected_order"])  # 写入表头
    for compound, order in results:
        writer.writerow([compound, order])

print(f"Results saved to {output_file}")
# Out:
# Processing compound: elbow grease
# Compound: elbow grease
# Image ID: 74852536462.png
# Input Text: Compound: elbow grease. Explanation: Hard physical effort or manual labor required to complete a task.
# Logits: tensor([[25.1573]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: elbow grease
# Image ID: 53378381715.png
# Input Text: Compound: elbow grease. Explanation: Hard physical effort or manual labor required to complete a task.
# Logits: tensor([[30.1589]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: elbow grease
# Image ID: 39938261459.png
# Input Text: Compound: elbow grease. Explanation: Hard physical effort or manual labor required to complete a task.
# Logits: tensor([[31.1292]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: elbow grease
# Image ID: 54879908369.png
# Input Text: Compound: elbow grease. Explanation: Hard physical effort or manual labor required to complete a task.
# Logits: tensor([[23.7950]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: elbow grease
# Image ID: 35234427395.png
# Input Text: Compound: elbow grease. Explanation: Hard physical effort or manual labor required to complete a task.
# Logits: tensor([[22.2846]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: night owl
# Compound: night owl
# Image ID: 93541983868.png
# Input Text: Compound: night owl. Explanation: A person who stays up late at night or is active during the night.
# Logits: tensor([[21.0273]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: night owl
# Image ID: 00982495584.png
# Input Text: Compound: night owl. Explanation: A person who stays up late at night or is active during the night.
# Logits: tensor([[30.7551]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: night owl
# Image ID: 61697797701.png
# Input Text: Compound: night owl. Explanation: A person who stays up late at night or is active during the night.
# Logits: tensor([[27.0066]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: night owl
# Image ID: 89375227504.png
# Input Text: Compound: night owl. Explanation: A person who stays up late at night or is active during the night.
# Logits: tensor([[27.8111]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: night owl
# Image ID: 93189810779.png
# Input Text: Compound: night owl. Explanation: A person who stays up late at night or is active during the night.
# Logits: tensor([[27.8282]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: heart of gold
# Compound: heart of gold
# Image ID: 86137977215.png
# Input Text: Compound: heart of gold. Explanation: A kind, generous, and compassionate nature.
# Logits: tensor([[23.4807]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: heart of gold
# Image ID: 92088849364.png
# Input Text: Compound: heart of gold. Explanation: A kind, generous, and compassionate nature.
# Logits: tensor([[29.5858]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: heart of gold
# Image ID: 54240592941.png
# Input Text: Compound: heart of gold. Explanation: A kind, generous, and compassionate nature.
# Logits: tensor([[23.6615]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: heart of gold
# Image ID: 78062290185.png
# Input Text: Compound: heart of gold. Explanation: A kind, generous, and compassionate nature.
# Logits: tensor([[22.6712]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: heart of gold
# Image ID: 90660547751.png
# Input Text: Compound: heart of gold. Explanation: A kind, generous, and compassionate nature.
# Logits: tensor([[16.6009]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: agony aunt
# Compound: agony aunt
# Image ID: 57658144685.png
# Input Text: Compound: agony aunt. Explanation: A person, often a columnist, who offers advice and sympathy to those seeking help with personal problems.
# Logits: tensor([[22.6779]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: agony aunt
# Image ID: 92533456778.png
# Input Text: Compound: agony aunt. Explanation: A person, often a columnist, who offers advice and sympathy to those seeking help with personal problems.
# Logits: tensor([[24.8268]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: agony aunt
# Image ID: 02512838127.png
# Input Text: Compound: agony aunt. Explanation: A person, often a columnist, who offers advice and sympathy to those seeking help with personal problems.
# Logits: tensor([[22.2702]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: agony aunt
# Image ID: 83600499282.png
# Input Text: Compound: agony aunt. Explanation: A person, often a columnist, who offers advice and sympathy to those seeking help with personal problems.
# Logits: tensor([[25.9796]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: agony aunt
# Image ID: 32964421720.png
# Input Text: Compound: agony aunt. Explanation: A person, often a columnist, who offers advice and sympathy to those seeking help with personal problems.
# Logits: tensor([[25.0422]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: shrinking violet
# Compound: shrinking violet
# Image ID: 77861539717.png
# Input Text: Compound: shrinking violet. Explanation: A shy, timid, or introverted person who avoids attention.
# Logits: tensor([[26.7894]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: shrinking violet
# Image ID: 11844321898.png
# Input Text: Compound: shrinking violet. Explanation: A shy, timid, or introverted person who avoids attention.
# Logits: tensor([[25.4969]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: shrinking violet
# Image ID: 97482048489.png
# Input Text: Compound: shrinking violet. Explanation: A shy, timid, or introverted person who avoids attention.
# Logits: tensor([[20.4933]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: shrinking violet
# Image ID: 45394842176.png
# Input Text: Compound: shrinking violet. Explanation: A shy, timid, or introverted person who avoids attention.
# Logits: tensor([[27.6131]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: shrinking violet
# Image ID: 68016869942.png
# Input Text: Compound: shrinking violet. Explanation: A shy, timid, or introverted person who avoids attention.
# Logits: tensor([[23.9088]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: banana republic
# Compound: banana republic
# Image ID: 59540059198.png
# Input Text: Compound: banana republic. Explanation: A politically unstable country, often economically dependent on a single export, typically governed by a corrupt or authoritarian regime.
# Logits: tensor([[25.3417]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: banana republic
# Image ID: 42960735833.png
# Input Text: Compound: banana republic. Explanation: A politically unstable country, often economically dependent on a single export, typically governed by a corrupt or authoritarian regime.
# Logits: tensor([[24.3761]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: banana republic
# Image ID: 14331448769.png
# Input Text: Compound: banana republic. Explanation: A politically unstable country, often economically dependent on a single export, typically governed by a corrupt or authoritarian regime.
# Logits: tensor([[23.3821]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: banana republic
# Image ID: 09384622843.png
# Input Text: Compound: banana republic. Explanation: A politically unstable country, often economically dependent on a single export, typically governed by a corrupt or authoritarian regime.
# Logits: tensor([[23.0375]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: banana republic
# Image ID: 54445954523.png
# Input Text: Compound: banana republic. Explanation: A politically unstable country, often economically dependent on a single export, typically governed by a corrupt or authoritarian regime.
# Logits: tensor([[18.9131]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: private eye
# Compound: private eye
# Image ID: 42541218123.png
# Input Text: Compound: private eye. Explanation: A private detective or investigator hired to gather information or solve cases.
# Logits: tensor([[23.3958]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: private eye
# Image ID: 86990947307.png
# Input Text: Compound: private eye. Explanation: A private detective or investigator hired to gather information or solve cases.
# Logits: tensor([[27.2490]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: private eye
# Image ID: 37448041335.png
# Input Text: Compound: private eye. Explanation: A private detective or investigator hired to gather information or solve cases.
# Logits: tensor([[21.4767]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: private eye
# Image ID: 66264001169.png
# Input Text: Compound: private eye. Explanation: A private detective or investigator hired to gather information or solve cases.
# Logits: tensor([[25.3360]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: private eye
# Image ID: 95762945875.png
# Input Text: Compound: private eye. Explanation: A private detective or investigator hired to gather information or solve cases.
# Logits: tensor([[26.1040]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: pipe dream
# Compound: pipe dream
# Image ID: 75172836336.png
# Input Text: Compound: pipe dream. Explanation: An unrealistic or impractical hope or plan.
# Logits: tensor([[22.4567]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pipe dream
# Image ID: 41486582831.png
# Input Text: Compound: pipe dream. Explanation: An unrealistic or impractical hope or plan.
# Logits: tensor([[24.2085]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pipe dream
# Image ID: 57336253001.png
# Input Text: Compound: pipe dream. Explanation: An unrealistic or impractical hope or plan.
# Logits: tensor([[22.4228]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pipe dream
# Image ID: 89899531949.png
# Input Text: Compound: pipe dream. Explanation: An unrealistic or impractical hope or plan.
# Logits: tensor([[26.2699]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pipe dream
# Image ID: 02795863019.png
# Input Text: Compound: pipe dream. Explanation: An unrealistic or impractical hope or plan.
# Logits: tensor([[24.2116]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: rocket science
# Compound: rocket science
# Image ID: 83472329575.png
# Input Text: Compound: rocket science. Explanation: Something very complex or difficult to understand.
# Logits: tensor([[20.2239]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rocket science
# Image ID: 05490541317.png
# Input Text: Compound: rocket science. Explanation: Something very complex or difficult to understand.
# Logits: tensor([[27.3890]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rocket science
# Image ID: 89043407312.png
# Input Text: Compound: rocket science. Explanation: Something very complex or difficult to understand.
# Logits: tensor([[20.9009]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rocket science
# Image ID: 66888109136.png
# Input Text: Compound: rocket science. Explanation: Something very complex or difficult to understand.
# Logits: tensor([[22.2445]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rocket science
# Image ID: 61309592117.png
# Input Text: Compound: rocket science. Explanation: Something very complex or difficult to understand.
# Logits: tensor([[19.2902]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: nest egg
# Compound: nest egg
# Image ID: 18562114617.png
# Input Text: Compound: nest egg. Explanation: Savings set aside for future use, especially for retirement or emergencies.
# Logits: tensor([[21.2783]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: nest egg
# Image ID: 62701169481.png
# Input Text: Compound: nest egg. Explanation: Savings set aside for future use, especially for retirement or emergencies.
# Logits: tensor([[23.8511]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: nest egg
# Image ID: 02370420010.png
# Input Text: Compound: nest egg. Explanation: Savings set aside for future use, especially for retirement or emergencies.
# Logits: tensor([[27.1870]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: nest egg
# Image ID: 61212005778.png
# Input Text: Compound: nest egg. Explanation: Savings set aside for future use, especially for retirement or emergencies.
# Logits: tensor([[34.0153]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: nest egg
# Image ID: 23144357017.png
# Input Text: Compound: nest egg. Explanation: Savings set aside for future use, especially for retirement or emergencies.
# Logits: tensor([[30.2580]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: bull market
# Compound: bull market
# Image ID: 55188636806.png
# Input Text: Compound: bull market. Explanation: A period of rising stock prices, reflecting investor confidence and economic growth.
# Logits: tensor([[27.1665]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bull market
# Image ID: 16206684278.png
# Input Text: Compound: bull market. Explanation: A period of rising stock prices, reflecting investor confidence and economic growth.
# Logits: tensor([[27.8112]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bull market
# Image ID: 02072099056.png
# Input Text: Compound: bull market. Explanation: A period of rising stock prices, reflecting investor confidence and economic growth.
# Logits: tensor([[19.8556]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bull market
# Image ID: 32267606120.png
# Input Text: Compound: bull market. Explanation: A period of rising stock prices, reflecting investor confidence and economic growth.
# Logits: tensor([[26.4965]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bull market
# Image ID: 52868171709.png
# Input Text: Compound: bull market. Explanation: A period of rising stock prices, reflecting investor confidence and economic growth.
# Logits: tensor([[28.3678]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: beached whale
# Compound: beached whale
# Image ID: 29988565894.png
# Input Text: Compound: beached whale. Explanation: A person or object that is stranded or stuck in an awkward or immobile position, often due to size or inability to move.
# Logits: tensor([[23.1113]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: beached whale
# Image ID: 67110850257.png
# Input Text: Compound: beached whale. Explanation: A person or object that is stranded or stuck in an awkward or immobile position, often due to size or inability to move.
# Logits: tensor([[31.9927]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: beached whale
# Image ID: 10430203037.png
# Input Text: Compound: beached whale. Explanation: A person or object that is stranded or stuck in an awkward or immobile position, often due to size or inability to move.
# Logits: tensor([[17.1862]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: beached whale
# Image ID: 44697847461.png
# Input Text: Compound: beached whale. Explanation: A person or object that is stranded or stuck in an awkward or immobile position, often due to size or inability to move.
# Logits: tensor([[18.7271]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: beached whale
# Image ID: 37685710911.png
# Input Text: Compound: beached whale. Explanation: A person or object that is stranded or stuck in an awkward or immobile position, often due to size or inability to move.
# Logits: tensor([[25.5294]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: lounge lizard
# Compound: lounge lizard
# Image ID: 98466676612.png
# Input Text: Compound: lounge lizard. Explanation: A man who frequents social venues to charm or seduce wealthy women, often seen as idle or insincere.
# Logits: tensor([[23.9786]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: lounge lizard
# Image ID: 60914711661.png
# Input Text: Compound: lounge lizard. Explanation: A man who frequents social venues to charm or seduce wealthy women, often seen as idle or insincere.
# Logits: tensor([[28.5160]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: lounge lizard
# Image ID: 90408626150.png
# Input Text: Compound: lounge lizard. Explanation: A man who frequents social venues to charm or seduce wealthy women, often seen as idle or insincere.
# Logits: tensor([[26.9994]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: lounge lizard
# Image ID: 89810040757.png
# Input Text: Compound: lounge lizard. Explanation: A man who frequents social venues to charm or seduce wealthy women, often seen as idle or insincere.
# Logits: tensor([[21.1476]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: lounge lizard
# Image ID: 71941017088.png
# Input Text: Compound: lounge lizard. Explanation: A man who frequents social venues to charm or seduce wealthy women, often seen as idle or insincere.
# Logits: tensor([[19.9541]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: bear market
# Compound: bear market
# Image ID: 99596916072.png
# Input Text: Compound: bear market. Explanation: A period of declining stock prices, typically marked by investor pessimism and widespread selling.
# Logits: tensor([[19.9410]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bear market
# Image ID: 34535041645.png
# Input Text: Compound: bear market. Explanation: A period of declining stock prices, typically marked by investor pessimism and widespread selling.
# Logits: tensor([[28.1047]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bear market
# Image ID: 41056104334.png
# Input Text: Compound: bear market. Explanation: A period of declining stock prices, typically marked by investor pessimism and widespread selling.
# Logits: tensor([[28.2840]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bear market
# Image ID: 81444958673.png
# Input Text: Compound: bear market. Explanation: A period of declining stock prices, typically marked by investor pessimism and widespread selling.
# Logits: tensor([[17.9962]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bear market
# Image ID: 81955291670.png
# Input Text: Compound: bear market. Explanation: A period of declining stock prices, typically marked by investor pessimism and widespread selling.
# Logits: tensor([[26.2582]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: white hat
# Compound: white hat
# Image ID: 50305046415.png
# Input Text: Compound: white hat. Explanation: A person who uses their hacking skills for ethical purposes, such as improving security or exposing vulnerabilities.
# Logits: tensor([[23.3266]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white hat
# Image ID: 13755461305.png
# Input Text: Compound: white hat. Explanation: A person who uses their hacking skills for ethical purposes, such as improving security or exposing vulnerabilities.
# Logits: tensor([[28.5796]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white hat
# Image ID: 12124292214.png
# Input Text: Compound: white hat. Explanation: A person who uses their hacking skills for ethical purposes, such as improving security or exposing vulnerabilities.
# Logits: tensor([[19.9120]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white hat
# Image ID: 11696820520.png
# Input Text: Compound: white hat. Explanation: A person who uses their hacking skills for ethical purposes, such as improving security or exposing vulnerabilities.
# Logits: tensor([[25.4591]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white hat
# Image ID: 39481587509.png
# Input Text: Compound: white hat. Explanation: A person who uses their hacking skills for ethical purposes, such as improving security or exposing vulnerabilities.
# Logits: tensor([[27.9266]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: smoking gun
# Compound: smoking gun
# Image ID: 32526851715.png
# Input Text: Compound: smoking gun. Explanation: Clear and undeniable evidence of wrongdoing or guilt.
# Logits: tensor([[18.9047]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: smoking gun
# Image ID: 22927734727.png
# Input Text: Compound: smoking gun. Explanation: Clear and undeniable evidence of wrongdoing or guilt.
# Logits: tensor([[20.2959]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: smoking gun
# Image ID: 58880185181.png
# Input Text: Compound: smoking gun. Explanation: Clear and undeniable evidence of wrongdoing or guilt.
# Logits: tensor([[30.8620]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: smoking gun
# Image ID: 57957044165.png
# Input Text: Compound: smoking gun. Explanation: Clear and undeniable evidence of wrongdoing or guilt.
# Logits: tensor([[22.3154]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: smoking gun
# Image ID: 30396026278.png
# Input Text: Compound: smoking gun. Explanation: Clear and undeniable evidence of wrongdoing or guilt.
# Logits: tensor([[26.8428]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: old flame
# Compound: old flame
# Image ID: 31217316388.png
# Input Text: Compound: old flame. Explanation: A former romantic partner or someone with whom one had a past romantic relationship.
# Logits: tensor([[25.2178]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: old flame
# Image ID: 06168811595.png
# Input Text: Compound: old flame. Explanation: A former romantic partner or someone with whom one had a past romantic relationship.
# Logits: tensor([[20.5029]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: old flame
# Image ID: 47140387353.png
# Input Text: Compound: old flame. Explanation: A former romantic partner or someone with whom one had a past romantic relationship.
# Logits: tensor([[23.2562]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: old flame
# Image ID: 35771360108.png
# Input Text: Compound: old flame. Explanation: A former romantic partner or someone with whom one had a past romantic relationship.
# Logits: tensor([[27.3557]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: old flame
# Image ID: 17267051988.png
# Input Text: Compound: old flame. Explanation: A former romantic partner or someone with whom one had a past romantic relationship.
# Logits: tensor([[27.5673]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: ivory tower
# Compound: ivory tower
# Image ID: 39323799209.png
# Input Text: Compound: ivory tower. Explanation: A state of privileged seclusion or separation from the practical concerns of everyday life, often used to describe academia or intellectual pursuits.
# Logits: tensor([[24.8228]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ivory tower
# Image ID: 09597167816.png
# Input Text: Compound: ivory tower. Explanation: A state of privileged seclusion or separation from the practical concerns of everyday life, often used to describe academia or intellectual pursuits.
# Logits: tensor([[23.3371]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ivory tower
# Image ID: 19861926689.png
# Input Text: Compound: ivory tower. Explanation: A state of privileged seclusion or separation from the practical concerns of everyday life, often used to describe academia or intellectual pursuits.
# Logits: tensor([[21.1992]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ivory tower
# Image ID: 45153820818.png
# Input Text: Compound: ivory tower. Explanation: A state of privileged seclusion or separation from the practical concerns of everyday life, often used to describe academia or intellectual pursuits.
# Logits: tensor([[26.2039]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ivory tower
# Image ID: 05445068868.png
# Input Text: Compound: ivory tower. Explanation: A state of privileged seclusion or separation from the practical concerns of everyday life, often used to describe academia or intellectual pursuits.
# Logits: tensor([[22.5440]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: black sheep
# Compound: black sheep
# Image ID: 40244159873.png
# Input Text: Compound: black sheep. Explanation: A person who is considered a disgrace or an outlier in a family or group.
# Logits: tensor([[21.7632]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black sheep
# Image ID: 80118206373.png
# Input Text: Compound: black sheep. Explanation: A person who is considered a disgrace or an outlier in a family or group.
# Logits: tensor([[20.0001]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black sheep
# Image ID: 52872475612.png
# Input Text: Compound: black sheep. Explanation: A person who is considered a disgrace or an outlier in a family or group.
# Logits: tensor([[31.3352]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black sheep
# Image ID: 94022502719.png
# Input Text: Compound: black sheep. Explanation: A person who is considered a disgrace or an outlier in a family or group.
# Logits: tensor([[28.6228]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black sheep
# Image ID: 85414168973.png
# Input Text: Compound: black sheep. Explanation: A person who is considered a disgrace or an outlier in a family or group.
# Logits: tensor([[20.9418]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: gravy train
# Compound: gravy train
# Image ID: 57293389133.png
# Input Text: Compound: gravy train. Explanation: A situation of easy money or financial gain with little effort.
# Logits: tensor([[20.0642]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: gravy train
# Image ID: 54540831700.png
# Input Text: Compound: gravy train. Explanation: A situation of easy money or financial gain with little effort.
# Logits: tensor([[29.1664]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: gravy train
# Image ID: 98011817158.png
# Input Text: Compound: gravy train. Explanation: A situation of easy money or financial gain with little effort.
# Logits: tensor([[23.3812]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: gravy train
# Image ID: 65362654761.png
# Input Text: Compound: gravy train. Explanation: A situation of easy money or financial gain with little effort.
# Logits: tensor([[23.6670]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: gravy train
# Image ID: 65809438894.png
# Input Text: Compound: gravy train. Explanation: A situation of easy money or financial gain with little effort.
# Logits: tensor([[25.0489]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: rat race
# Compound: rat race
# Image ID: 27816548474.png
# Input Text: Compound: rat race. Explanation: A competitive struggle to achieve success, often in a stressful or exhausting way, typically in the workplace or modern life.
# Logits: tensor([[28.9433]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat race
# Image ID: 45504234188.png
# Input Text: Compound: rat race. Explanation: A competitive struggle to achieve success, often in a stressful or exhausting way, typically in the workplace or modern life.
# Logits: tensor([[21.5174]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat race
# Image ID: 04209106095.png
# Input Text: Compound: rat race. Explanation: A competitive struggle to achieve success, often in a stressful or exhausting way, typically in the workplace or modern life.
# Logits: tensor([[30.1311]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat race
# Image ID: 28647406758.png
# Input Text: Compound: rat race. Explanation: A competitive struggle to achieve success, often in a stressful or exhausting way, typically in the workplace or modern life.
# Logits: tensor([[23.5177]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat race
# Image ID: 97737199528.png
# Input Text: Compound: rat race. Explanation: A competitive struggle to achieve success, often in a stressful or exhausting way, typically in the workplace or modern life.
# Logits: tensor([[33.1815]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: spring chicken
# Compound: spring chicken
# Image ID: 76118640398.png
# Input Text: Compound: spring chicken. Explanation: A young or inexperienced person, often used to imply someone is no longer young.
# Logits: tensor([[23.2727]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: spring chicken
# Image ID: 66116309434.png
# Input Text: Compound: spring chicken. Explanation: A young or inexperienced person, often used to imply someone is no longer young.
# Logits: tensor([[31.4902]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: spring chicken
# Image ID: 81474137778.png
# Input Text: Compound: spring chicken. Explanation: A young or inexperienced person, often used to imply someone is no longer young.
# Logits: tensor([[29.9468]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: spring chicken
# Image ID: 57301692989.png
# Input Text: Compound: spring chicken. Explanation: A young or inexperienced person, often used to imply someone is no longer young.
# Logits: tensor([[20.4073]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: spring chicken
# Image ID: 20324325790.png
# Input Text: Compound: spring chicken. Explanation: A young or inexperienced person, often used to imply someone is no longer young.
# Logits: tensor([[22.0814]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: inner circle
# Compound: inner circle
# Image ID: 69620536561.png
# Input Text: Compound: inner circle. Explanation: A small, exclusive group of people with shared interests or influence, often close to a leader or decision-maker.
# Logits: tensor([[22.9495]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: inner circle
# Image ID: 74028690231.png
# Input Text: Compound: inner circle. Explanation: A small, exclusive group of people with shared interests or influence, often close to a leader or decision-maker.
# Logits: tensor([[22.1845]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: inner circle
# Image ID: 60203367715.png
# Input Text: Compound: inner circle. Explanation: A small, exclusive group of people with shared interests or influence, often close to a leader or decision-maker.
# Logits: tensor([[25.9535]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: inner circle
# Image ID: 34506090318.png
# Input Text: Compound: inner circle. Explanation: A small, exclusive group of people with shared interests or influence, often close to a leader or decision-maker.
# Logits: tensor([[21.8638]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: inner circle
# Image ID: 32590417205.png
# Input Text: Compound: inner circle. Explanation: A small, exclusive group of people with shared interests or influence, often close to a leader or decision-maker.
# Logits: tensor([[26.7328]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: bad apple
# Compound: bad apple
# Image ID: 82053252112.png
# Input Text: Compound: bad apple. Explanation: A person who causes trouble or has a negative influence on others within a group.
# Logits: tensor([[28.1636]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bad apple
# Image ID: 78200848882.png
# Input Text: Compound: bad apple. Explanation: A person who causes trouble or has a negative influence on others within a group.
# Logits: tensor([[26.6630]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bad apple
# Image ID: 43074669652.png
# Input Text: Compound: bad apple. Explanation: A person who causes trouble or has a negative influence on others within a group.
# Logits: tensor([[24.3915]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bad apple
# Image ID: 39242366111.png
# Input Text: Compound: bad apple. Explanation: A person who causes trouble or has a negative influence on others within a group.
# Logits: tensor([[24.9386]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bad apple
# Image ID: 87462057419.png
# Input Text: Compound: bad apple. Explanation: A person who causes trouble or has a negative influence on others within a group.
# Logits: tensor([[25.2299]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: honey trap
# Compound: honey trap
# Image ID: 66042334676.png
# Input Text: Compound: honey trap. Explanation: A deceptive tactic where someone uses charm or allure to entrap or manipulate another person, often for espionage, blackmail, or personal gain.
# Logits: tensor([[27.1400]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: honey trap
# Image ID: 35168957863.png
# Input Text: Compound: honey trap. Explanation: A deceptive tactic where someone uses charm or allure to entrap or manipulate another person, often for espionage, blackmail, or personal gain.
# Logits: tensor([[25.9058]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: honey trap
# Image ID: 13606752629.png
# Input Text: Compound: honey trap. Explanation: A deceptive tactic where someone uses charm or allure to entrap or manipulate another person, often for espionage, blackmail, or personal gain.
# Logits: tensor([[21.8987]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: honey trap
# Image ID: 39822764653.png
# Input Text: Compound: honey trap. Explanation: A deceptive tactic where someone uses charm or allure to entrap or manipulate another person, often for espionage, blackmail, or personal gain.
# Logits: tensor([[25.1714]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: honey trap
# Image ID: 37674249712.png
# Input Text: Compound: honey trap. Explanation: A deceptive tactic where someone uses charm or allure to entrap or manipulate another person, often for espionage, blackmail, or personal gain.
# Logits: tensor([[26.5135]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: open book
# Compound: open book
# Image ID: 58632881432.png
# Input Text: Compound: open book. Explanation: A person or thing that is easy to understand or interpret; transparent and without secrets.
# Logits: tensor([[26.2726]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: open book
# Image ID: 34251825412.png
# Input Text: Compound: open book. Explanation: A person or thing that is easy to understand or interpret; transparent and without secrets.
# Logits: tensor([[22.3116]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: open book
# Image ID: 59859593427.png
# Input Text: Compound: open book. Explanation: A person or thing that is easy to understand or interpret; transparent and without secrets.
# Logits: tensor([[18.3455]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: open book
# Image ID: 06126366716.png
# Input Text: Compound: open book. Explanation: A person or thing that is easy to understand or interpret; transparent and without secrets.
# Logits: tensor([[27.9122]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: open book
# Image ID: 64138598987.png
# Input Text: Compound: open book. Explanation: A person or thing that is easy to understand or interpret; transparent and without secrets.
# Logits: tensor([[22.1404]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: baby blues
# Compound: baby blues
# Image ID: 46456209569.png
# Input Text: Compound: baby blues. Explanation: Feelings of sadness or depression experienced by some women after giving birth.
# Logits: tensor([[19.2782]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: baby blues
# Image ID: 04071685511.png
# Input Text: Compound: baby blues. Explanation: Feelings of sadness or depression experienced by some women after giving birth.
# Logits: tensor([[25.4842]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: baby blues
# Image ID: 60185641466.png
# Input Text: Compound: baby blues. Explanation: Feelings of sadness or depression experienced by some women after giving birth.
# Logits: tensor([[20.9940]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: baby blues
# Image ID: 91570497980.png
# Input Text: Compound: baby blues. Explanation: Feelings of sadness or depression experienced by some women after giving birth.
# Logits: tensor([[19.6200]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: baby blues
# Image ID: 78529931749.png
# Input Text: Compound: baby blues. Explanation: Feelings of sadness or depression experienced by some women after giving birth.
# Logits: tensor([[22.9547]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: brain surgery
# Compound: brain surgery
# Image ID: 20059340578.png
# Input Text: Compound: brain surgery. Explanation: A task or activity that is extremely complex or difficult to understand or perform.
# Logits: tensor([[28.6400]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brain surgery
# Image ID: 14221797226.png
# Input Text: Compound: brain surgery. Explanation: A task or activity that is extremely complex or difficult to understand or perform.
# Logits: tensor([[22.5068]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brain surgery
# Image ID: 00389092717.png
# Input Text: Compound: brain surgery. Explanation: A task or activity that is extremely complex or difficult to understand or perform.
# Logits: tensor([[22.2550]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brain surgery
# Image ID: 14803973068.png
# Input Text: Compound: brain surgery. Explanation: A task or activity that is extremely complex or difficult to understand or perform.
# Logits: tensor([[20.7287]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brain surgery
# Image ID: 77652241695.png
# Input Text: Compound: brain surgery. Explanation: A task or activity that is extremely complex or difficult to understand or perform.
# Logits: tensor([[30.8460]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: red flag
# Compound: red flag
# Image ID: 88424293285.png
# Input Text: Compound: red flag. Explanation: A warning sign or indication of a potential problem or danger.
# Logits: tensor([[32.0712]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: red flag
# Image ID: 49339545808.png
# Input Text: Compound: red flag. Explanation: A warning sign or indication of a potential problem or danger.
# Logits: tensor([[19.0640]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: red flag
# Image ID: 59390351123.png
# Input Text: Compound: red flag. Explanation: A warning sign or indication of a potential problem or danger.
# Logits: tensor([[21.9456]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: red flag
# Image ID: 63105721515.png
# Input Text: Compound: red flag. Explanation: A warning sign or indication of a potential problem or danger.
# Logits: tensor([[22.0080]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: red flag
# Image ID: 31173191426.png
# Input Text: Compound: red flag. Explanation: A warning sign or indication of a potential problem or danger.
# Logits: tensor([[22.7771]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: white elephant
# Compound: white elephant
# Image ID: 14504224870.png
# Input Text: Compound: white elephant. Explanation: A costly or burdensome possession that is difficult to maintain or dispose of.
# Logits: tensor([[22.6089]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white elephant
# Image ID: 61362577917.png
# Input Text: Compound: white elephant. Explanation: A costly or burdensome possession that is difficult to maintain or dispose of.
# Logits: tensor([[24.7543]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white elephant
# Image ID: 81445236099.png
# Input Text: Compound: white elephant. Explanation: A costly or burdensome possession that is difficult to maintain or dispose of.
# Logits: tensor([[22.1540]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white elephant
# Image ID: 95221758898.png
# Input Text: Compound: white elephant. Explanation: A costly or burdensome possession that is difficult to maintain or dispose of.
# Logits: tensor([[21.1943]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: white elephant
# Image ID: 25156360931.png
# Input Text: Compound: white elephant. Explanation: A costly or burdensome possession that is difficult to maintain or dispose of.
# Logits: tensor([[21.9322]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: rat run
# Compound: rat run
# Image ID: 94938520064.png
# Input Text: Compound: rat run. Explanation: A shortcut or minor road used to avoid traffic, often by drivers familiar with the area.
# Logits: tensor([[26.8637]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat run
# Image ID: 60896460729.png
# Input Text: Compound: rat run. Explanation: A shortcut or minor road used to avoid traffic, often by drivers familiar with the area.
# Logits: tensor([[26.3312]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat run
# Image ID: 55855203654.png
# Input Text: Compound: rat run. Explanation: A shortcut or minor road used to avoid traffic, often by drivers familiar with the area.
# Logits: tensor([[28.2226]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat run
# Image ID: 32737581165.png
# Input Text: Compound: rat run. Explanation: A shortcut or minor road used to avoid traffic, often by drivers familiar with the area.
# Logits: tensor([[22.1765]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: rat run
# Image ID: 87303309822.png
# Input Text: Compound: rat run. Explanation: A shortcut or minor road used to avoid traffic, often by drivers familiar with the area.
# Logits: tensor([[28.7467]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: graveyard shift
# Compound: graveyard shift
# Image ID: 50809642929.png
# Input Text: Compound: graveyard shift. Explanation: A work shift that occurs late at night or early in the morning, typically from midnight to 8 a.m.
# Logits: tensor([[24.5361]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: graveyard shift
# Image ID: 50466267708.png
# Input Text: Compound: graveyard shift. Explanation: A work shift that occurs late at night or early in the morning, typically from midnight to 8 a.m.
# Logits: tensor([[24.6270]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: graveyard shift
# Image ID: 83947965924.png
# Input Text: Compound: graveyard shift. Explanation: A work shift that occurs late at night or early in the morning, typically from midnight to 8 a.m.
# Logits: tensor([[25.7694]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: graveyard shift
# Image ID: 11712779940.png
# Input Text: Compound: graveyard shift. Explanation: A work shift that occurs late at night or early in the morning, typically from midnight to 8 a.m.
# Logits: tensor([[18.6818]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: graveyard shift
# Image ID: 39559921078.png
# Input Text: Compound: graveyard shift. Explanation: A work shift that occurs late at night or early in the morning, typically from midnight to 8 a.m.
# Logits: tensor([[21.2090]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: dirty money
# Compound: dirty money
# Image ID: 58491774071.png
# Input Text: Compound: dirty money. Explanation: Money obtained through illegal or unethical means, often associated with corruption or crime.
# Logits: tensor([[21.1342]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty money
# Image ID: 24738184590.png
# Input Text: Compound: dirty money. Explanation: Money obtained through illegal or unethical means, often associated with corruption or crime.
# Logits: tensor([[25.6897]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty money
# Image ID: 08230960409.png
# Input Text: Compound: dirty money. Explanation: Money obtained through illegal or unethical means, often associated with corruption or crime.
# Logits: tensor([[27.2675]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty money
# Image ID: 46913780614.png
# Input Text: Compound: dirty money. Explanation: Money obtained through illegal or unethical means, often associated with corruption or crime.
# Logits: tensor([[26.6061]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty money
# Image ID: 62777714452.png
# Input Text: Compound: dirty money. Explanation: Money obtained through illegal or unethical means, often associated with corruption or crime.
# Logits: tensor([[26.0378]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: high life
# Compound: high life
# Image ID: 06164272353.png
# Input Text: Compound: high life. Explanation: A luxurious and glamorous lifestyle, often associated with wealth, parties, and social prestige.
# Logits: tensor([[18.4046]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: high life
# Image ID: 39122642061.png
# Input Text: Compound: high life. Explanation: A luxurious and glamorous lifestyle, often associated with wealth, parties, and social prestige.
# Logits: tensor([[19.4608]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: high life
# Image ID: 40542311053.png
# Input Text: Compound: high life. Explanation: A luxurious and glamorous lifestyle, often associated with wealth, parties, and social prestige.
# Logits: tensor([[23.6494]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: high life
# Image ID: 49516114391.png
# Input Text: Compound: high life. Explanation: A luxurious and glamorous lifestyle, often associated with wealth, parties, and social prestige.
# Logits: tensor([[23.6987]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: high life
# Image ID: 49177713448.png
# Input Text: Compound: high life. Explanation: A luxurious and glamorous lifestyle, often associated with wealth, parties, and social prestige.
# Logits: tensor([[21.1842]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: pain in the neck
# Compound: pain in the neck
# Image ID: 59520456167.png
# Input Text: Compound: pain in the neck. Explanation: A source of annoyance or frustration.
# Logits: tensor([[20.0113]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pain in the neck
# Image ID: 99595459963.png
# Input Text: Compound: pain in the neck. Explanation: A source of annoyance or frustration.
# Logits: tensor([[25.3599]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pain in the neck
# Image ID: 08190047042.png
# Input Text: Compound: pain in the neck. Explanation: A source of annoyance or frustration.
# Logits: tensor([[30.4069]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pain in the neck
# Image ID: 86378892255.png
# Input Text: Compound: pain in the neck. Explanation: A source of annoyance or frustration.
# Logits: tensor([[21.2555]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pain in the neck
# Image ID: 06915129382.png
# Input Text: Compound: pain in the neck. Explanation: A source of annoyance or frustration.
# Logits: tensor([[18.4155]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: guinea pig
# Compound: guinea pig
# Image ID: 14575503360.png
# Input Text: Compound: guinea pig. Explanation: A person used as a subject for experimentation or testing.
# Logits: tensor([[22.6025]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: guinea pig
# Image ID: 20717384670.png
# Input Text: Compound: guinea pig. Explanation: A person used as a subject for experimentation or testing.
# Logits: tensor([[19.3981]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: guinea pig
# Image ID: 05733696351.png
# Input Text: Compound: guinea pig. Explanation: A person used as a subject for experimentation or testing.
# Logits: tensor([[23.1751]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: guinea pig
# Image ID: 37944668726.png
# Input Text: Compound: guinea pig. Explanation: A person used as a subject for experimentation or testing.
# Logits: tensor([[24.5750]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: guinea pig
# Image ID: 66149700285.png
# Input Text: Compound: guinea pig. Explanation: A person used as a subject for experimentation or testing.
# Logits: tensor([[32.9765]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Skipping compound: cat's eyes (folder does not exist)
# Processing compound: low-hanging fruit
# Compound: low-hanging fruit
# Image ID: 91117857131.png
# Input Text: Compound: low-hanging fruit. Explanation: Easily achievable goals or tasks that require minimal effort to accomplish.
# Logits: tensor([[30.2546]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: low-hanging fruit
# Image ID: 87359560017.png
# Input Text: Compound: low-hanging fruit. Explanation: Easily achievable goals or tasks that require minimal effort to accomplish.
# Logits: tensor([[23.6288]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: low-hanging fruit
# Image ID: 42866872474.png
# Input Text: Compound: low-hanging fruit. Explanation: Easily achievable goals or tasks that require minimal effort to accomplish.
# Logits: tensor([[29.7322]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: low-hanging fruit
# Image ID: 20825217491.png
# Input Text: Compound: low-hanging fruit. Explanation: Easily achievable goals or tasks that require minimal effort to accomplish.
# Logits: tensor([[23.4831]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: low-hanging fruit
# Image ID: 28404294077.png
# Input Text: Compound: low-hanging fruit. Explanation: Easily achievable goals or tasks that require minimal effort to accomplish.
# Logits: tensor([[21.5797]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: busy bee
# Compound: busy bee
# Image ID: 27532602036.png
# Input Text: Compound: busy bee. Explanation: A person who is very active, hardworking, or constantly occupied with tasks.
# Logits: tensor([[24.4501]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: busy bee
# Image ID: 50516840411.png
# Input Text: Compound: busy bee. Explanation: A person who is very active, hardworking, or constantly occupied with tasks.
# Logits: tensor([[30.5751]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: busy bee
# Image ID: 13914680332.png
# Input Text: Compound: busy bee. Explanation: A person who is very active, hardworking, or constantly occupied with tasks.
# Logits: tensor([[31.1668]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: busy bee
# Image ID: 33246843335.png
# Input Text: Compound: busy bee. Explanation: A person who is very active, hardworking, or constantly occupied with tasks.
# Logits: tensor([[24.8299]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: busy bee
# Image ID: 50206720330.png
# Input Text: Compound: busy bee. Explanation: A person who is very active, hardworking, or constantly occupied with tasks.
# Logits: tensor([[19.1189]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Results saved to train_idiom.tsv

# %%
import os
import json
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import csv

# 加载模型和处理器
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# 指定主文件夹路径和 JSON 文件路径
main_folder_path = "/content/drive/MyDrive/train"  # 替换为你的实际路径
json_file_path = "/content/drive/MyDrive/train_literal_mean.json"   # 替换为你的 JSON 文件路径


# 加载 JSON 文件
with open(json_file_path, "r", encoding="utf-8") as json_file:
    compound_definitions = json.load(json_file)

# 初始化结果存储
results = []

# 遍历 JSON 中的 compound 定义
for compound_name, compound_text in compound_definitions.items():
    compound_path = os.path.join(main_folder_path, compound_name)

    # 检查文件夹是否存在
    if not os.path.isdir(compound_path):
        print(f"Skipping compound: {compound_name} (folder does not exist)")
        continue

    print(f"Processing compound: {compound_name}")

    # 将 compound 和解释拼接为一个完整文本
    combined_text = f"Compound: {compound_name}. Explanation: {compound_text}"

    # 用于存储当前 compound 的图片及其 logits
    image_logits = []

    # 遍历子文件夹中的图片
    for filename in os.listdir(compound_path):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):  # 仅处理图片文件
            image_path = os.path.join(compound_path, filename)

            # 打开图片
            try:
                image = Image.open(image_path)
            except Exception as e:
                print(f"Error opening image {filename}: {e}")
                continue

            # 使用 compound 和解释拼接后的文本作为输入
            inputs = processor(
                text=[combined_text],  # 拼接后的文本输入
                images=image,
                return_tensors="pt",
                padding=True
            )

            # 获取模型输出
            outputs = model(**inputs)
            logits_per_image = outputs.logits_per_image  # 获取 logits 值

            # 打印日志信息
            print(f"Compound: {compound_name}")
            print(f"Image ID: {filename}")  # 保留文件名及后缀
            print(f"Input Text: {combined_text}")
            print(f"Logits: {logits_per_image}")
            print("-" * 50)

            # 保存图片文件名（包含后缀）和 logits
            image_logits.append((filename, logits_per_image.item()))

    # 按 logits 从大到小排序
    sorted_images = sorted(image_logits, key=lambda x: x[1], reverse=True)

    # 提取排序后的图片文件名列表
    expected_order = [img[0] for img in sorted_images]

    # 保存 compound 和排序列表
    results.append([compound_name, expected_order])

# 将结果保存为 TSV 文件
output_file = "train_literal.tsv"
with open(output_file, "w", newline="", encoding="utf-8") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    writer.writerow(["compound", "expected_order"])  # 写入表头
    for compound, order in results:
        writer.writerow([compound, order])

print(f"Results saved to {output_file}")
# Out:
# Processing compound: green fingers
# Compound: green fingers
# Image ID: 88406435457.png
# Input Text: Compound: green fingers. Explanation: Fingers that are colored green, either due to paint, dye, or other substances.
# Logits: tensor([[27.0648]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: green fingers
# Image ID: 88683770392.png
# Input Text: Compound: green fingers. Explanation: Fingers that are colored green, either due to paint, dye, or other substances.
# Logits: tensor([[21.0476]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: green fingers
# Image ID: 10027562830.png
# Input Text: Compound: green fingers. Explanation: Fingers that are colored green, either due to paint, dye, or other substances.
# Logits: tensor([[25.2555]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: green fingers
# Image ID: 92628846416.png
# Input Text: Compound: green fingers. Explanation: Fingers that are colored green, either due to paint, dye, or other substances.
# Logits: tensor([[27.7292]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: green fingers
# Image ID: 38213294711.png
# Input Text: Compound: green fingers. Explanation: Fingers that are colored green, either due to paint, dye, or other substances.
# Logits: tensor([[31.4238]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: ancient history
# Compound: ancient history
# Image ID: 89162981347.png
# Input Text: Compound: ancient history. Explanation: The study or record of events, people, and societies from the distant past, typically before the Middle Ages.
# Logits: tensor([[22.1320]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ancient history
# Image ID: 20677180119.png
# Input Text: Compound: ancient history. Explanation: The study or record of events, people, and societies from the distant past, typically before the Middle Ages.
# Logits: tensor([[23.5764]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ancient history
# Image ID: 97760341223.png
# Input Text: Compound: ancient history. Explanation: The study or record of events, people, and societies from the distant past, typically before the Middle Ages.
# Logits: tensor([[26.3205]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ancient history
# Image ID: 91744816929.png
# Input Text: Compound: ancient history. Explanation: The study or record of events, people, and societies from the distant past, typically before the Middle Ages.
# Logits: tensor([[21.9961]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ancient history
# Image ID: 80235397834.png
# Input Text: Compound: ancient history. Explanation: The study or record of events, people, and societies from the distant past, typically before the Middle Ages.
# Logits: tensor([[19.9945]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Skipping compound: devil's advocate (folder does not exist)
# Processing compound: piece of cake
# Compound: piece of cake
# Image ID: 04237996522.png
# Input Text: Compound: piece of cake. Explanation: A portion or slice of a baked dessert made from flour, sugar, eggs, and other ingredients.
# Logits: tensor([[28.1860]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: piece of cake
# Image ID: 55124577858.png
# Input Text: Compound: piece of cake. Explanation: A portion or slice of a baked dessert made from flour, sugar, eggs, and other ingredients.
# Logits: tensor([[20.8662]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: piece of cake
# Image ID: 96911519929.png
# Input Text: Compound: piece of cake. Explanation: A portion or slice of a baked dessert made from flour, sugar, eggs, and other ingredients.
# Logits: tensor([[20.2020]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: piece of cake
# Image ID: 78485019666.png
# Input Text: Compound: piece of cake. Explanation: A portion or slice of a baked dessert made from flour, sugar, eggs, and other ingredients.
# Logits: tensor([[29.4011]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: piece of cake
# Image ID: 84842839046.png
# Input Text: Compound: piece of cake. Explanation: A portion or slice of a baked dessert made from flour, sugar, eggs, and other ingredients.
# Logits: tensor([[21.2903]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: brass ring
# Compound: brass ring
# Image ID: 95672336968.png
# Input Text: Compound: brass ring. Explanation: A ring made of brass, often used as a decorative or functional item.
# Logits: tensor([[17.9194]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brass ring
# Image ID: 65189326623.png
# Input Text: Compound: brass ring. Explanation: A ring made of brass, often used as a decorative or functional item.
# Logits: tensor([[18.0183]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brass ring
# Image ID: 51003386336.png
# Input Text: Compound: brass ring. Explanation: A ring made of brass, often used as a decorative or functional item.
# Logits: tensor([[21.6766]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brass ring
# Image ID: 80706529304.png
# Input Text: Compound: brass ring. Explanation: A ring made of brass, often used as a decorative or functional item.
# Logits: tensor([[25.6885]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: brass ring
# Image ID: 96956947028.png
# Input Text: Compound: brass ring. Explanation: A ring made of brass, often used as a decorative or functional item.
# Logits: tensor([[30.9570]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: apples and oranges
# Compound: apples and oranges
# Image ID: 06670601370.png
# Input Text: Compound: apples and oranges. Explanation: Two different types of fruits, specifically apples and oranges.
# Logits: tensor([[29.9156]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: apples and oranges
# Image ID: 47167686168.png
# Input Text: Compound: apples and oranges. Explanation: Two different types of fruits, specifically apples and oranges.
# Logits: tensor([[23.8087]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: apples and oranges
# Image ID: 06706738051.png
# Input Text: Compound: apples and oranges. Explanation: Two different types of fruits, specifically apples and oranges.
# Logits: tensor([[19.3986]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: apples and oranges
# Image ID: 34972099351.png
# Input Text: Compound: apples and oranges. Explanation: Two different types of fruits, specifically apples and oranges.
# Logits: tensor([[31.6558]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: apples and oranges
# Image ID: 78981196177.png
# Input Text: Compound: apples and oranges. Explanation: Two different types of fruits, specifically apples and oranges.
# Logits: tensor([[19.7363]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: ghost town
# Compound: ghost town
# Image ID: 81343436490.png
# Input Text: Compound: ghost town. Explanation: A deserted town with no remaining inhabitants, often in a state of decay.
# Logits: tensor([[26.9498]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ghost town
# Image ID: 08510094453.png
# Input Text: Compound: ghost town. Explanation: A deserted town with no remaining inhabitants, often in a state of decay.
# Logits: tensor([[20.5272]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ghost town
# Image ID: 96149834283.png
# Input Text: Compound: ghost town. Explanation: A deserted town with no remaining inhabitants, often in a state of decay.
# Logits: tensor([[20.7800]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ghost town
# Image ID: 95676628446.png
# Input Text: Compound: ghost town. Explanation: A deserted town with no remaining inhabitants, often in a state of decay.
# Logits: tensor([[19.2435]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: ghost town
# Image ID: 77229322693.png
# Input Text: Compound: ghost town. Explanation: A deserted town with no remaining inhabitants, often in a state of decay.
# Logits: tensor([[24.3382]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: flower child
# Compound: flower child
# Image ID: 70564136759.png
# Input Text: Compound: flower child. Explanation: A young child who is associated with or resembles a flower, often in appearance or innocence.
# Logits: tensor([[26.3689]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flower child
# Image ID: 31939147449.png
# Input Text: Compound: flower child. Explanation: A young child who is associated with or resembles a flower, often in appearance or innocence.
# Logits: tensor([[29.4981]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flower child
# Image ID: 27113356190.png
# Input Text: Compound: flower child. Explanation: A young child who is associated with or resembles a flower, often in appearance or innocence.
# Logits: tensor([[21.5935]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flower child
# Image ID: 71677279296.png
# Input Text: Compound: flower child. Explanation: A young child who is associated with or resembles a flower, often in appearance or innocence.
# Logits: tensor([[22.0038]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flower child
# Image ID: 66547801519.png
# Input Text: Compound: flower child. Explanation: A young child who is associated with or resembles a flower, often in appearance or innocence.
# Logits: tensor([[22.6983]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: copy cat
# Compound: copy cat
# Image ID: 82047847966.png
# Input Text: Compound: copy cat. Explanation: A cat that imitates or copies the actions of another cat or animal.
# Logits: tensor([[21.2427]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: copy cat
# Image ID: 24801323866.png
# Input Text: Compound: copy cat. Explanation: A cat that imitates or copies the actions of another cat or animal.
# Logits: tensor([[19.4268]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: copy cat
# Image ID: 82991780025.png
# Input Text: Compound: copy cat. Explanation: A cat that imitates or copies the actions of another cat or animal.
# Logits: tensor([[21.1228]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: copy cat
# Image ID: 76230045663.png
# Input Text: Compound: copy cat. Explanation: A cat that imitates or copies the actions of another cat or animal.
# Logits: tensor([[29.2515]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: copy cat
# Image ID: 39497588644.png
# Input Text: Compound: copy cat. Explanation: A cat that imitates or copies the actions of another cat or animal.
# Logits: tensor([[27.6295]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: secret santa
# Compound: secret santa
# Image ID: 73884284579.png
# Input Text: Compound: secret santa. Explanation: A person named Santa who is secretive or keeps their identity hidden.
# Logits: tensor([[27.8666]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: secret santa
# Image ID: 53937857464.png
# Input Text: Compound: secret santa. Explanation: A person named Santa who is secretive or keeps their identity hidden.
# Logits: tensor([[29.8595]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: secret santa
# Image ID: 83896740010.png
# Input Text: Compound: secret santa. Explanation: A person named Santa who is secretive or keeps their identity hidden.
# Logits: tensor([[22.1340]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: secret santa
# Image ID: 43315095878.png
# Input Text: Compound: secret santa. Explanation: A person named Santa who is secretive or keeps their identity hidden.
# Logits: tensor([[24.6942]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: secret santa
# Image ID: 43012219877.png
# Input Text: Compound: secret santa. Explanation: A person named Santa who is secretive or keeps their identity hidden.
# Logits: tensor([[31.4926]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: dirty word
# Compound: dirty word
# Image ID: 24899523859.png
# Input Text: Compound: dirty word. Explanation: A word that is considered vulgar, offensive, or inappropriate in language.
# Logits: tensor([[19.1367]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty word
# Image ID: 14069763077.png
# Input Text: Compound: dirty word. Explanation: A word that is considered vulgar, offensive, or inappropriate in language.
# Logits: tensor([[20.2492]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty word
# Image ID: 06993539786.png
# Input Text: Compound: dirty word. Explanation: A word that is considered vulgar, offensive, or inappropriate in language.
# Logits: tensor([[22.6581]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty word
# Image ID: 36466202137.png
# Input Text: Compound: dirty word. Explanation: A word that is considered vulgar, offensive, or inappropriate in language.
# Logits: tensor([[23.2023]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: dirty word
# Image ID: 44754936991.png
# Input Text: Compound: dirty word. Explanation: A word that is considered vulgar, offensive, or inappropriate in language.
# Logits: tensor([[23.6020]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: close shave
# Compound: close shave
# Image ID: 61687169887.png
# Input Text: Compound: close shave. Explanation: A shave performed with a razor that cuts hair very close to the skin, leaving a smooth finish.
# Logits: tensor([[29.8368]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: close shave
# Image ID: 15095694666.png
# Input Text: Compound: close shave. Explanation: A shave performed with a razor that cuts hair very close to the skin, leaving a smooth finish.
# Logits: tensor([[17.6669]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: close shave
# Image ID: 89483662888.png
# Input Text: Compound: close shave. Explanation: A shave performed with a razor that cuts hair very close to the skin, leaving a smooth finish.
# Logits: tensor([[17.9608]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: close shave
# Image ID: 55410405875.png
# Input Text: Compound: close shave. Explanation: A shave performed with a razor that cuts hair very close to the skin, leaving a smooth finish.
# Logits: tensor([[21.3955]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: close shave
# Image ID: 36654367033.png
# Input Text: Compound: close shave. Explanation: A shave performed with a razor that cuts hair very close to the skin, leaving a smooth finish.
# Logits: tensor([[27.2559]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: donkey work
# Compound: donkey work
# Image ID: 18911527144.png
# Input Text: Compound: donkey work. Explanation: The physical labor or tasks performed by a donkey, such as carrying loads or pulling carts.
# Logits: tensor([[29.7778]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: donkey work
# Image ID: 21236393136.png
# Input Text: Compound: donkey work. Explanation: The physical labor or tasks performed by a donkey, such as carrying loads or pulling carts.
# Logits: tensor([[25.3419]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: donkey work
# Image ID: 18787432584.png
# Input Text: Compound: donkey work. Explanation: The physical labor or tasks performed by a donkey, such as carrying loads or pulling carts.
# Logits: tensor([[31.0456]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: donkey work
# Image ID: 06637246420.png
# Input Text: Compound: donkey work. Explanation: The physical labor or tasks performed by a donkey, such as carrying loads or pulling carts.
# Logits: tensor([[14.4418]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: donkey work
# Image ID: 20662025964.png
# Input Text: Compound: donkey work. Explanation: The physical labor or tasks performed by a donkey, such as carrying loads or pulling carts.
# Logits: tensor([[20.2334]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: top dog
# Compound: top dog
# Image ID: 43207170783.png
# Input Text: Compound: top dog. Explanation: The highest-ranking or most dominant dog in a group.
# Logits: tensor([[26.4972]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: top dog
# Image ID: 62040589986.png
# Input Text: Compound: top dog. Explanation: The highest-ranking or most dominant dog in a group.
# Logits: tensor([[29.6023]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: top dog
# Image ID: 44297130521.png
# Input Text: Compound: top dog. Explanation: The highest-ranking or most dominant dog in a group.
# Logits: tensor([[20.8734]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: top dog
# Image ID: 76177115752.png
# Input Text: Compound: top dog. Explanation: The highest-ranking or most dominant dog in a group.
# Logits: tensor([[23.6273]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: top dog
# Image ID: 38568900802.png
# Input Text: Compound: top dog. Explanation: The highest-ranking or most dominant dog in a group.
# Logits: tensor([[20.6890]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Skipping compound: dog's dinner (folder does not exist)
# Processing compound: zebra crossing
# Compound: zebra crossing
# Image ID: 50338175575.png
# Input Text: Compound: zebra crossing. Explanation: A pedestrian crossing marked with white stripes resembling a zebra's pattern, used to indicate where pedestrians can safely cross the road.
# Logits: tensor([[18.5830]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: zebra crossing
# Image ID: 24926483896.png
# Input Text: Compound: zebra crossing. Explanation: A pedestrian crossing marked with white stripes resembling a zebra's pattern, used to indicate where pedestrians can safely cross the road.
# Logits: tensor([[27.8325]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: zebra crossing
# Image ID: 62775742958.png
# Input Text: Compound: zebra crossing. Explanation: A pedestrian crossing marked with white stripes resembling a zebra's pattern, used to indicate where pedestrians can safely cross the road.
# Logits: tensor([[32.8595]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: zebra crossing
# Image ID: 69410806712.png
# Input Text: Compound: zebra crossing. Explanation: A pedestrian crossing marked with white stripes resembling a zebra's pattern, used to indicate where pedestrians can safely cross the road.
# Logits: tensor([[30.8989]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: zebra crossing
# Image ID: 58091284576.png
# Input Text: Compound: zebra crossing. Explanation: A pedestrian crossing marked with white stripes resembling a zebra's pattern, used to indicate where pedestrians can safely cross the road.
# Logits: tensor([[28.0035]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: eye candy
# Compound: eye candy
# Image ID: 74941070286.png
# Input Text: Compound: eye candy. Explanation: Candy shaped like or resembling an eye, often used as a decorative or novelty item.
# Logits: tensor([[27.0288]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eye candy
# Image ID: 67393713269.png
# Input Text: Compound: eye candy. Explanation: Candy shaped like or resembling an eye, often used as a decorative or novelty item.
# Logits: tensor([[22.9344]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eye candy
# Image ID: 77288299313.png
# Input Text: Compound: eye candy. Explanation: Candy shaped like or resembling an eye, often used as a decorative or novelty item.
# Logits: tensor([[20.5453]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eye candy
# Image ID: 33933826748.png
# Input Text: Compound: eye candy. Explanation: Candy shaped like or resembling an eye, often used as a decorative or novelty item.
# Logits: tensor([[31.0353]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eye candy
# Image ID: 00230957504.png
# Input Text: Compound: eye candy. Explanation: Candy shaped like or resembling an eye, often used as a decorative or novelty item.
# Logits: tensor([[18.0648]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: armchair critic
# Compound: armchair critic
# Image ID: 67127914712.png
# Input Text: Compound: armchair critic. Explanation: A person who sits in an armchair and criticizes others.
# Logits: tensor([[24.9747]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: armchair critic
# Image ID: 36891525128.png
# Input Text: Compound: armchair critic. Explanation: A person who sits in an armchair and criticizes others.
# Logits: tensor([[30.0621]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: armchair critic
# Image ID: 66678388745.png
# Input Text: Compound: armchair critic. Explanation: A person who sits in an armchair and criticizes others.
# Logits: tensor([[28.3808]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: armchair critic
# Image ID: 22768920335.png
# Input Text: Compound: armchair critic. Explanation: A person who sits in an armchair and criticizes others.
# Logits: tensor([[22.2441]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: armchair critic
# Image ID: 27123744055.png
# Input Text: Compound: armchair critic. Explanation: A person who sits in an armchair and criticizes others.
# Logits: tensor([[25.8308]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: hot potato
# Compound: hot potato
# Image ID: 31362616456.png
# Input Text: Compound: hot potato. Explanation: A potato that is hot in temperature, typically after being cooked.
# Logits: tensor([[18.9672]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hot potato
# Image ID: 73009108593.png
# Input Text: Compound: hot potato. Explanation: A potato that is hot in temperature, typically after being cooked.
# Logits: tensor([[30.1146]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hot potato
# Image ID: 95656943243.png
# Input Text: Compound: hot potato. Explanation: A potato that is hot in temperature, typically after being cooked.
# Logits: tensor([[18.8257]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hot potato
# Image ID: 84435539379.png
# Input Text: Compound: hot potato. Explanation: A potato that is hot in temperature, typically after being cooked.
# Logits: tensor([[16.7289]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hot potato
# Image ID: 20231777670.png
# Input Text: Compound: hot potato. Explanation: A potato that is hot in temperature, typically after being cooked.
# Logits: tensor([[29.9653]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: love triangle
# Compound: love triangle
# Image ID: 59548334929.png
# Input Text: Compound: love triangle. Explanation: A geometric shape with three sides, where each side represents a romantic relationship between three people.
# Logits: tensor([[27.1619]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: love triangle
# Image ID: 66352366466.png
# Input Text: Compound: love triangle. Explanation: A geometric shape with three sides, where each side represents a romantic relationship between three people.
# Logits: tensor([[24.9010]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: love triangle
# Image ID: 70080592856.png
# Input Text: Compound: love triangle. Explanation: A geometric shape with three sides, where each side represents a romantic relationship between three people.
# Logits: tensor([[27.9786]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: love triangle
# Image ID: 56377316808.png
# Input Text: Compound: love triangle. Explanation: A geometric shape with three sides, where each side represents a romantic relationship between three people.
# Logits: tensor([[21.2303]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: love triangle
# Image ID: 16857080306.png
# Input Text: Compound: love triangle. Explanation: A geometric shape with three sides, where each side represents a romantic relationship between three people.
# Logits: tensor([[22.7722]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: black box
# Compound: black box
# Image ID: 60904898706.png
# Input Text: Compound: black box. Explanation: A physical box that is black in color, often used to contain or protect something.
# Logits: tensor([[30.0355]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black box
# Image ID: 73920583487.png
# Input Text: Compound: black box. Explanation: A physical box that is black in color, often used to contain or protect something.
# Logits: tensor([[18.4167]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black box
# Image ID: 41077897719.png
# Input Text: Compound: black box. Explanation: A physical box that is black in color, often used to contain or protect something.
# Logits: tensor([[31.0050]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black box
# Image ID: 76956198734.png
# Input Text: Compound: black box. Explanation: A physical box that is black in color, often used to contain or protect something.
# Logits: tensor([[21.4605]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: black box
# Image ID: 82295944756.png
# Input Text: Compound: black box. Explanation: A physical box that is black in color, often used to contain or protect something.
# Logits: tensor([[21.3926]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: hen party
# Compound: hen party
# Image ID: 14218153967.png
# Input Text: Compound: hen party. Explanation: A gathering or party exclusively for hens (female chickens).
# Logits: tensor([[28.3712]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hen party
# Image ID: 77119535961.png
# Input Text: Compound: hen party. Explanation: A gathering or party exclusively for hens (female chickens).
# Logits: tensor([[30.6641]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hen party
# Image ID: 64751387734.png
# Input Text: Compound: hen party. Explanation: A gathering or party exclusively for hens (female chickens).
# Logits: tensor([[31.5500]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hen party
# Image ID: 37074365923.png
# Input Text: Compound: hen party. Explanation: A gathering or party exclusively for hens (female chickens).
# Logits: tensor([[21.6708]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hen party
# Image ID: 16686328418.png
# Input Text: Compound: hen party. Explanation: A gathering or party exclusively for hens (female chickens).
# Logits: tensor([[27.5490]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: acid test
# Compound: acid test
# Image ID: 02817176209.png
# Input Text: Compound: acid test. Explanation: A test using acid to determine the purity or quality of a substance, such as gold.
# Logits: tensor([[25.5880]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: acid test
# Image ID: 38840705602.png
# Input Text: Compound: acid test. Explanation: A test using acid to determine the purity or quality of a substance, such as gold.
# Logits: tensor([[19.5349]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: acid test
# Image ID: 03133054749.png
# Input Text: Compound: acid test. Explanation: A test using acid to determine the purity or quality of a substance, such as gold.
# Logits: tensor([[28.0410]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: acid test
# Image ID: 76398012989.png
# Input Text: Compound: acid test. Explanation: A test using acid to determine the purity or quality of a substance, such as gold.
# Logits: tensor([[19.9378]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: acid test
# Image ID: 45105971201.png
# Input Text: Compound: acid test. Explanation: A test using acid to determine the purity or quality of a substance, such as gold.
# Logits: tensor([[25.9363]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: pins and needles
# Compound: pins and needles
# Image ID: 18951355308.png
# Input Text: Compound: pins and needles. Explanation: Sharp, pointed objects used for sewing and small, thin metal tools used for fastening or piercing.
# Logits: tensor([[28.8811]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pins and needles
# Image ID: 62351469038.png
# Input Text: Compound: pins and needles. Explanation: Sharp, pointed objects used for sewing and small, thin metal tools used for fastening or piercing.
# Logits: tensor([[22.5213]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pins and needles
# Image ID: 69262707128.png
# Input Text: Compound: pins and needles. Explanation: Sharp, pointed objects used for sewing and small, thin metal tools used for fastening or piercing.
# Logits: tensor([[18.7967]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pins and needles
# Image ID: 31343098424.png
# Input Text: Compound: pins and needles. Explanation: Sharp, pointed objects used for sewing and small, thin metal tools used for fastening or piercing.
# Logits: tensor([[23.6306]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: pins and needles
# Image ID: 24771463968.png
# Input Text: Compound: pins and needles. Explanation: Sharp, pointed objects used for sewing and small, thin metal tools used for fastening or piercing.
# Logits: tensor([[21.7874]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: bun in the oven
# Compound: bun in the oven
# Image ID: 69447699784.png
# Input Text: Compound: bun in the oven. Explanation: A bread roll placed inside an oven for baking.
# Logits: tensor([[27.5509]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bun in the oven
# Image ID: 24126898562.png
# Input Text: Compound: bun in the oven. Explanation: A bread roll placed inside an oven for baking.
# Logits: tensor([[22.2234]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bun in the oven
# Image ID: 50796495623.png
# Input Text: Compound: bun in the oven. Explanation: A bread roll placed inside an oven for baking.
# Logits: tensor([[23.1423]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bun in the oven
# Image ID: 68092803556.png
# Input Text: Compound: bun in the oven. Explanation: A bread roll placed inside an oven for baking.
# Logits: tensor([[27.5509]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bun in the oven
# Image ID: 64309391652.png
# Input Text: Compound: bun in the oven. Explanation: A bread roll placed inside an oven for baking.
# Logits: tensor([[21.0029]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: loan shark
# Compound: loan shark
# Image ID: 36582309103.png
# Input Text: Compound: loan shark. Explanation: A predatory fish that lends money to other sea creatures at exorbitant interest rates.
# Logits: tensor([[19.8429]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: loan shark
# Image ID: 72575235835.png
# Input Text: Compound: loan shark. Explanation: A predatory fish that lends money to other sea creatures at exorbitant interest rates.
# Logits: tensor([[23.3105]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: loan shark
# Image ID: 57469910132.png
# Input Text: Compound: loan shark. Explanation: A predatory fish that lends money to other sea creatures at exorbitant interest rates.
# Logits: tensor([[32.5049]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: loan shark
# Image ID: 32211216966.png
# Input Text: Compound: loan shark. Explanation: A predatory fish that lends money to other sea creatures at exorbitant interest rates.
# Logits: tensor([[20.2848]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: loan shark
# Image ID: 91154880140.png
# Input Text: Compound: loan shark. Explanation: A predatory fish that lends money to other sea creatures at exorbitant interest rates.
# Logits: tensor([[28.7563]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: silver bullet
# Compound: silver bullet
# Image ID: 44193989525.png
# Input Text: Compound: silver bullet. Explanation: A bullet made of silver, often associated with folklore as a weapon against supernatural creatures like werewolves.
# Logits: tensor([[17.8527]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: silver bullet
# Image ID: 48187131860.png
# Input Text: Compound: silver bullet. Explanation: A bullet made of silver, often associated with folklore as a weapon against supernatural creatures like werewolves.
# Logits: tensor([[20.0544]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: silver bullet
# Image ID: 87765926961.png
# Input Text: Compound: silver bullet. Explanation: A bullet made of silver, often associated with folklore as a weapon against supernatural creatures like werewolves.
# Logits: tensor([[15.5164]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: silver bullet
# Image ID: 14577105224.png
# Input Text: Compound: silver bullet. Explanation: A bullet made of silver, often associated with folklore as a weapon against supernatural creatures like werewolves.
# Logits: tensor([[18.7829]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: silver bullet
# Image ID: 42403978271.png
# Input Text: Compound: silver bullet. Explanation: A bullet made of silver, often associated with folklore as a weapon against supernatural creatures like werewolves.
# Logits: tensor([[25.6261]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: two-way street
# Compound: two-way street
# Image ID: 70843122394.png
# Input Text: Compound: two-way street. Explanation: A street or road that allows traffic to move in both directions.
# Logits: tensor([[20.2736]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: two-way street
# Image ID: 02864043166.png
# Input Text: Compound: two-way street. Explanation: A street or road that allows traffic to move in both directions.
# Logits: tensor([[31.4130]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: two-way street
# Image ID: 77388092739.png
# Input Text: Compound: two-way street. Explanation: A street or road that allows traffic to move in both directions.
# Logits: tensor([[29.4136]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: two-way street
# Image ID: 64314348310.png
# Input Text: Compound: two-way street. Explanation: A street or road that allows traffic to move in both directions.
# Logits: tensor([[20.0995]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: two-way street
# Image ID: 83632254366.png
# Input Text: Compound: two-way street. Explanation: A street or road that allows traffic to move in both directions.
# Logits: tensor([[22.2213]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: cold turkey
# Compound: cold turkey
# Image ID: 78631376435.png
# Input Text: Compound: cold turkey. Explanation: A dish made from cooked turkey that has been served cold, often as leftovers or in sandwiches.
# Logits: tensor([[25.6442]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: cold turkey
# Image ID: 53986444390.png
# Input Text: Compound: cold turkey. Explanation: A dish made from cooked turkey that has been served cold, often as leftovers or in sandwiches.
# Logits: tensor([[21.5698]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: cold turkey
# Image ID: 65148693634.png
# Input Text: Compound: cold turkey. Explanation: A dish made from cooked turkey that has been served cold, often as leftovers or in sandwiches.
# Logits: tensor([[21.4375]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: cold turkey
# Image ID: 47545447824.png
# Input Text: Compound: cold turkey. Explanation: A dish made from cooked turkey that has been served cold, often as leftovers or in sandwiches.
# Logits: tensor([[24.6840]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: cold turkey
# Image ID: 16239351344.png
# Input Text: Compound: cold turkey. Explanation: A dish made from cooked turkey that has been served cold, often as leftovers or in sandwiches.
# Logits: tensor([[24.9147]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: wet blanket
# Compound: wet blanket
# Image ID: 88635314726.png
# Input Text: Compound: wet blanket. Explanation: A blanket that is wet or damp.
# Logits: tensor([[22.6302]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: wet blanket
# Image ID: 39385479814.png
# Input Text: Compound: wet blanket. Explanation: A blanket that is wet or damp.
# Logits: tensor([[19.3552]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: wet blanket
# Image ID: 64522104806.png
# Input Text: Compound: wet blanket. Explanation: A blanket that is wet or damp.
# Logits: tensor([[21.5337]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: wet blanket
# Image ID: 03496279195.png
# Input Text: Compound: wet blanket. Explanation: A blanket that is wet or damp.
# Logits: tensor([[19.7208]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: wet blanket
# Image ID: 28147683669.png
# Input Text: Compound: wet blanket. Explanation: A blanket that is wet or damp.
# Logits: tensor([[27.5491]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: chicken feed
# Compound: chicken feed
# Image ID: 37795851361.png
# Input Text: Compound: chicken feed. Explanation: Food given to chickens, typically consisting of grains or seeds.
# Logits: tensor([[30.2752]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chicken feed
# Image ID: 48528496115.png
# Input Text: Compound: chicken feed. Explanation: Food given to chickens, typically consisting of grains or seeds.
# Logits: tensor([[20.1852]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chicken feed
# Image ID: 57390097066.png
# Input Text: Compound: chicken feed. Explanation: Food given to chickens, typically consisting of grains or seeds.
# Logits: tensor([[28.9702]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chicken feed
# Image ID: 95410072019.png
# Input Text: Compound: chicken feed. Explanation: Food given to chickens, typically consisting of grains or seeds.
# Logits: tensor([[21.8459]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chicken feed
# Image ID: 21271058237.png
# Input Text: Compound: chicken feed. Explanation: Food given to chickens, typically consisting of grains or seeds.
# Logits: tensor([[19.4736]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Results saved to train_literal.tsv

# %%
import os
import json
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import csv

# 加载模型和处理器
model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# 指定主文件夹路径和 JSON 文件路径
main_folder_path = "/content/drive/MyDrive/AdMIRe Subtask A Dev/dev"  # 替换为你的实际路径
json_file_path = "/content/drive/MyDrive/dev_mean.json"   # 替换为你的 JSON 文件路径


# 加载 JSON 文件
with open(json_file_path, "r", encoding="utf-8") as json_file:
    compound_definitions = json.load(json_file)

# 初始化结果存储
results = []

# 遍历 JSON 中的 compound 定义
for compound_name, compound_text in compound_definitions.items():
    compound_path = os.path.join(main_folder_path, compound_name)

    # 检查文件夹是否存在
    if not os.path.isdir(compound_path):
        print(f"Skipping compound: {compound_name} (folder does not exist)")
        continue

    print(f"Processing compound: {compound_name}")

    # 将 compound 和解释拼接为一个完整文本
    combined_text = f"Compound: {compound_name}. Explanation: {compound_text}"

    # 用于存储当前 compound 的图片及其 logits
    image_logits = []

    # 遍历子文件夹中的图片
    for filename in os.listdir(compound_path):
        if filename.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".gif")):  # 仅处理图片文件
            image_path = os.path.join(compound_path, filename)

            # 打开图片
            try:
                image = Image.open(image_path)
            except Exception as e:
                print(f"Error opening image {filename}: {e}")
                continue

            # 使用 compound 和解释拼接后的文本作为输入
            inputs = processor(
                text=[combined_text],  # 拼接后的文本输入
                images=image,
                return_tensors="pt",
                padding=True
            )

            # 获取模型输出
            outputs = model(**inputs)
            logits_per_image = outputs.logits_per_image  # 获取 logits 值

            # 打印日志信息
            print(f"Compound: {compound_name}")
            print(f"Image ID: {filename}")  # 保留文件名及后缀
            print(f"Input Text: {combined_text}")
            print(f"Logits: {logits_per_image}")
            print("-" * 50)

            # 保存图片文件名（包含后缀）和 logits
            image_logits.append((filename, logits_per_image.item()))

    # 按 logits 从大到小排序
    sorted_images = sorted(image_logits, key=lambda x: x[1], reverse=True)

    # 提取排序后的图片文件名列表
    expected_order = [img[0] for img in sorted_images]

    # 保存 compound 和排序列表
    results.append([compound_name, expected_order])

# 将结果保存为 TSV 文件
output_file = "dev_with_description.tsv"
with open(output_file, "w", newline="", encoding="utf-8") as tsvfile:
    writer = csv.writer(tsvfile, delimiter="\t")
    writer.writerow(["compound", "expected_order"])  # 写入表头
    for compound, order in results:
        writer.writerow([compound, order])

print(f"Results saved to {output_file}")
# Out:
# Processing compound: monkey business
# Compound: monkey business
# Image ID: 61570020623
# Definition: Dishonest, mischievous, or deceitful behavior; foolish or silly actions.
# Logits: tensor([[22.0505]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: monkey business
# Image ID: 94990180734
# Definition: Dishonest, mischievous, or deceitful behavior; foolish or silly actions.
# Logits: tensor([[22.8387]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: monkey business
# Image ID: 33778559524
# Definition: Dishonest, mischievous, or deceitful behavior; foolish or silly actions.
# Logits: tensor([[23.0462]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: monkey business
# Image ID: 04129294826
# Definition: Dishonest, mischievous, or deceitful behavior; foolish or silly actions.
# Logits: tensor([[22.3907]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: monkey business
# Image ID: 56875274126
# Definition: Dishonest, mischievous, or deceitful behavior; foolish or silly actions.
# Logits: tensor([[21.6654]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: grass roots
# Compound: grass roots
# Image ID: 88610497135
# Definition: The roots of grass plants, typically found in the soil, which anchor the plant and absorb water and nutrients.
# Logits: tensor([[34.6750]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: grass roots
# Image ID: 72263394122
# Definition: The roots of grass plants, typically found in the soil, which anchor the plant and absorb water and nutrients.
# Logits: tensor([[21.5402]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: grass roots
# Image ID: 29204334751
# Definition: The roots of grass plants, typically found in the soil, which anchor the plant and absorb water and nutrients.
# Logits: tensor([[19.6366]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: grass roots
# Image ID: 24221318591
# Definition: The roots of grass plants, typically found in the soil, which anchor the plant and absorb water and nutrients.
# Logits: tensor([[17.2139]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: grass roots
# Image ID: 50278959002
# Definition: The roots of grass plants, typically found in the soil, which anchor the plant and absorb water and nutrients.
# Logits: tensor([[27.5081]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: marching orders
# Compound: marching orders
# Image ID: 13776626434
# Definition: Official instructions given to soldiers or a group to begin marching or moving in a specific direction.
# Logits: tensor([[20.3296]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: marching orders
# Image ID: 06066676443
# Definition: Official instructions given to soldiers or a group to begin marching or moving in a specific direction.
# Logits: tensor([[16.7016]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: marching orders
# Image ID: 65125915005
# Definition: Official instructions given to soldiers or a group to begin marching or moving in a specific direction.
# Logits: tensor([[26.8360]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: marching orders
# Image ID: 15183305624
# Definition: Official instructions given to soldiers or a group to begin marching or moving in a specific direction.
# Logits: tensor([[16.9627]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: marching orders
# Image ID: 47713768923
# Definition: Official instructions given to soldiers or a group to begin marching or moving in a specific direction.
# Logits: tensor([[16.5175]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: panda car
# Compound: panda car
# Image ID: 29615068658
# Definition: A small, black-and-white police patrol car, resembling the colors of a panda, used for patrolling neighborhoods.
# Logits: tensor([[12.7880]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: panda car
# Image ID: 52866539701
# Definition: A small, black-and-white police patrol car, resembling the colors of a panda, used for patrolling neighborhoods.
# Logits: tensor([[25.7351]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: panda car
# Image ID: 63963578494
# Definition: A small, black-and-white police patrol car, resembling the colors of a panda, used for patrolling neighborhoods.
# Logits: tensor([[22.0727]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: panda car
# Image ID: 38506509761
# Definition: A small, black-and-white police patrol car, resembling the colors of a panda, used for patrolling neighborhoods.
# Logits: tensor([[30.2161]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: panda car
# Image ID: 42283780809
# Definition: A small, black-and-white police patrol car, resembling the colors of a panda, used for patrolling neighborhoods.
# Logits: tensor([[28.8099]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: bread and butter
# Compound: bread and butter
# Image ID: 96897123911
# Definition: A person's primary source of income or main livelihood.
# Logits: tensor([[22.5488]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bread and butter
# Image ID: 78076369814
# Definition: A person's primary source of income or main livelihood.
# Logits: tensor([[23.0533]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bread and butter
# Image ID: 47437883453
# Definition: A person's primary source of income or main livelihood.
# Logits: tensor([[21.6964]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bread and butter
# Image ID: 29490290047
# Definition: A person's primary source of income or main livelihood.
# Logits: tensor([[23.7103]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: bread and butter
# Image ID: 98148844665
# Definition: A person's primary source of income or main livelihood.
# Logits: tensor([[23.1726]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: chocolate teapot
# Compound: chocolate teapot
# Image ID: 10077984673
# Definition: A teapot made entirely of chocolate, used for decorative or novelty purposes rather than functional use.
# Logits: tensor([[30.2187]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chocolate teapot
# Image ID: 69053841503
# Definition: A teapot made entirely of chocolate, used for decorative or novelty purposes rather than functional use.
# Logits: tensor([[12.8100]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chocolate teapot
# Image ID: 24249382249
# Definition: A teapot made entirely of chocolate, used for decorative or novelty purposes rather than functional use.
# Logits: tensor([[35.5243]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chocolate teapot
# Image ID: 19286356455
# Definition: A teapot made entirely of chocolate, used for decorative or novelty purposes rather than functional use.
# Logits: tensor([[12.7133]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: chocolate teapot
# Image ID: 26164380699
# Definition: A teapot made entirely of chocolate, used for decorative or novelty purposes rather than functional use.
# Logits: tensor([[16.5395]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Skipping compound: pig's ear (folder does not exist)
# Processing compound: best man
# Compound: best man
# Image ID: 06108380384
# Definition: The groom's chief attendant at a wedding, responsible for supporting him and often giving a speech.
# Logits: tensor([[24.6939]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: best man
# Image ID: 12494202211
# Definition: The groom's chief attendant at a wedding, responsible for supporting him and often giving a speech.
# Logits: tensor([[15.8241]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: best man
# Image ID: 57504389911
# Definition: The groom's chief attendant at a wedding, responsible for supporting him and often giving a speech.
# Logits: tensor([[15.8057]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: best man
# Image ID: 95555063454
# Definition: The groom's chief attendant at a wedding, responsible for supporting him and often giving a speech.
# Logits: tensor([[27.4440]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: best man
# Image ID: 94431397208
# Definition: The groom's chief attendant at a wedding, responsible for supporting him and often giving a speech.
# Logits: tensor([[22.2106]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: big cheese
# Compound: big cheese
# Image ID: 83903589871
# Definition: A large piece of cheese.
# Logits: tensor([[19.5261]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big cheese
# Image ID: 22784021150
# Definition: A large piece of cheese.
# Logits: tensor([[30.9482]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big cheese
# Image ID: 17957919543
# Definition: A large piece of cheese.
# Logits: tensor([[19.5771]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big cheese
# Image ID: 67845423017
# Definition: A large piece of cheese.
# Logits: tensor([[26.1388]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big cheese
# Image ID: 11983691096
# Definition: A large piece of cheese.
# Logits: tensor([[26.8179]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: eager beaver
# Compound: eager beaver
# Image ID: 25688411798
# Definition: A person who is extremely enthusiastic, hardworking, or eager to do something, often to the point of being overly zealous.
# Logits: tensor([[24.0047]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eager beaver
# Image ID: 40199113311
# Definition: A person who is extremely enthusiastic, hardworking, or eager to do something, often to the point of being overly zealous.
# Logits: tensor([[20.1899]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eager beaver
# Image ID: 51848512303
# Definition: A person who is extremely enthusiastic, hardworking, or eager to do something, often to the point of being overly zealous.
# Logits: tensor([[21.6894]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eager beaver
# Image ID: 97713215186
# Definition: A person who is extremely enthusiastic, hardworking, or eager to do something, often to the point of being overly zealous.
# Logits: tensor([[22.8827]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: eager beaver
# Image ID: 55745563240
# Definition: A person who is extremely enthusiastic, hardworking, or eager to do something, often to the point of being overly zealous.
# Logits: tensor([[21.1170]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: hair of the dog
# Compound: hair of the dog
# Image ID: 34696117377
# Definition: A strand or piece of hair from a dog.
# Logits: tensor([[17.9288]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hair of the dog
# Image ID: 40980576471
# Definition: A strand or piece of hair from a dog.
# Logits: tensor([[19.5772]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hair of the dog
# Image ID: 92505052147
# Definition: A strand or piece of hair from a dog.
# Logits: tensor([[27.9266]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hair of the dog
# Image ID: 83469211622
# Definition: A strand or piece of hair from a dog.
# Logits: tensor([[16.4109]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: hair of the dog
# Image ID: 65521182288
# Definition: A strand or piece of hair from a dog.
# Logits: tensor([[17.2118]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: thin ice
# Compound: thin ice
# Image ID: 30974936012
# Definition: A risky or dangerous situation where one must be cautious to avoid trouble.
# Logits: tensor([[21.7256]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: thin ice
# Image ID: 68101243143
# Definition: A risky or dangerous situation where one must be cautious to avoid trouble.
# Logits: tensor([[22.0426]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: thin ice
# Image ID: 66964681897
# Definition: A risky or dangerous situation where one must be cautious to avoid trouble.
# Logits: tensor([[26.8995]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: thin ice
# Image ID: 56231634037
# Definition: A risky or dangerous situation where one must be cautious to avoid trouble.
# Logits: tensor([[26.3554]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: thin ice
# Image ID: 38172236941
# Definition: A risky or dangerous situation where one must be cautious to avoid trouble.
# Logits: tensor([[26.1097]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: snake in the grass
# Compound: snake in the grass
# Image ID: 37599507851
# Definition: A deceitful or treacherous person who pretends to be a friend.
# Logits: tensor([[23.2832]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: snake in the grass
# Image ID: 06740727918
# Definition: A deceitful or treacherous person who pretends to be a friend.
# Logits: tensor([[20.3372]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: snake in the grass
# Image ID: 52162362542
# Definition: A deceitful or treacherous person who pretends to be a friend.
# Logits: tensor([[20.4483]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: snake in the grass
# Image ID: 54576306947
# Definition: A deceitful or treacherous person who pretends to be a friend.
# Logits: tensor([[19.3486]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: snake in the grass
# Image ID: 49936872564
# Definition: A deceitful or treacherous person who pretends to be a friend.
# Logits: tensor([[20.9083]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: flea market
# Compound: flea market
# Image ID: 03787129942
# Definition: A market where second-hand goods, antiques, or used items are sold, often outdoors or in a casual setting.
# Logits: tensor([[24.8972]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flea market
# Image ID: 61975753763
# Definition: A market where second-hand goods, antiques, or used items are sold, often outdoors or in a casual setting.
# Logits: tensor([[28.0686]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flea market
# Image ID: 14188009512
# Definition: A market where second-hand goods, antiques, or used items are sold, often outdoors or in a casual setting.
# Logits: tensor([[18.3241]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flea market
# Image ID: 39357147663
# Definition: A market where second-hand goods, antiques, or used items are sold, often outdoors or in a casual setting.
# Logits: tensor([[20.6355]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: flea market
# Image ID: 70941962850
# Definition: A market where second-hand goods, antiques, or used items are sold, often outdoors or in a casual setting.
# Logits: tensor([[24.3081]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Processing compound: big fish
# Compound: big fish
# Image ID: 10705988694
# Definition: A large aquatic animal, typically a fish of considerable size.
# Logits: tensor([[19.2946]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big fish
# Image ID: 66431812447
# Definition: A large aquatic animal, typically a fish of considerable size.
# Logits: tensor([[29.9430]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big fish
# Image ID: 81669241003
# Definition: A large aquatic animal, typically a fish of considerable size.
# Logits: tensor([[19.2065]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big fish
# Image ID: 15310725066
# Definition: A large aquatic animal, typically a fish of considerable size.
# Logits: tensor([[23.7161]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Compound: big fish
# Image ID: 95477779500
# Definition: A large aquatic animal, typically a fish of considerable size.
# Logits: tensor([[18.9770]], grad_fn=<TBackward0>)
# --------------------------------------------------
# Results saved to dev_with_description.tsv
